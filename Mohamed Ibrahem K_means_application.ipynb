# %% [markdown]
# # <a name="0">Hierarchical Clustering</a>

# %% [markdown]
# 1. <a href="#0">Read the dataset</a>
# 2. <a href="#2">Data investigation</a>
# 3. <a href="#3">Data preprocessing </a>
# 4. <a href="#4">Features transformation </a>
# 5. <a href="#5">K means</a>
# 6. <a href="#5">Training datasets</a>
# 7. <a href="#6">Improvement ideas</a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. <a name="1">Read the dataset</a>
# (<a href="#0">Go to top</a>)
#
# First dowmload the data set from this link https://www.kaggle.com/code/sadkoktaybicici/credit-card-data-clustering-k-mean/data
# then import it in python.

# %%
#read the data
data_path = ''  #the path where you downloaded the data
df = pd.read_csv('CC GENERAL.csv')
print('The shape of the dataset is:', df.shape)
df
# Out:
# The shape of the dataset is: (8950, 18)
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %% [markdown]
# ## 2. <a name="2">Data investigation</a>
# (<a href="#0">Go to top</a>)
#
# in this part you need to check the data quality and assess any issues in the data as:
# - null values in each column
# - each column has the proper data type
# - outliers
# - duplicate rows
# - distribution for each column (skewness)
# <br>
#
# **comment each issue you find**

# %%
# Let's see the data types and non-null values for each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
#CHECKING NULL VALUES which is there is 3.55 is null in 'MINIMUM_PAYMENTS'
round(df.isnull().sum(axis=0)*100/df.shape[0],2)
# Out:
# CUST_ID                             0.00
# BALANCE                             0.00
# BALANCE_FREQUENCY                   0.00
# PURCHASES                           0.00
# ONEOFF_PURCHASES                    0.00
# INSTALLMENTS_PURCHASES              0.00
# CASH_ADVANCE                        0.00
# PURCHASES_FREQUENCY                 0.00
# ONEOFF_PURCHASES_FREQUENCY          0.00
# PURCHASES_INSTALLMENTS_FREQUENCY    0.00
# CASH_ADVANCE_FREQUENCY              0.00
# CASH_ADVANCE_TRX                    0.00
# PURCHASES_TRX                       0.00
# CREDIT_LIMIT                        0.01
# PAYMENTS                            0.00
# MINIMUM_PAYMENTS                    3.50
# PRC_FULL_PAYMENT                    0.00
# TENURE                              0.00
# dtype: float64

# %%
# This will print basic statistics for numerical columns
df.describe().T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# PURCHASES_TRX                     8950.0    14.709832    24.857649   0.000000
# CREDIT_LIMIT                      8949.0  4494.449450  3638.815725  50.000000
# PAYMENTS                          8950.0  1733.143852  2895.063757   0.000000
# MINIMUM_PAYMENTS                  8637.0   864.206542  2372.446607   0.019163
# PRC_FULL_PAYMENT                  8950.0     0.153715     0.292499   0.000000
# TENURE                            8950.0    11.517318     1.338331   6.000000
#
#                                           25%          50%          75%  \
# BALANCE                            128.281915   873.385231  2054.140036
# BALANCE_FREQUENCY                    0.888889     1.000000     1.000000
# PURCHASES                           39.635000   361.280000  1110.130000
# ONEOFF_PURCHASES                     0.000000    38.000000   577.405000
# INSTALLMENTS_PURCHASES               0.000000    89.000000   468.637500
# CASH_ADVANCE                         0.000000     0.000000  1113.821139
# PURCHASES_FREQUENCY                  0.083333     0.500000     0.916667
# ONEOFF_PURCHASES_FREQUENCY           0.000000     0.083333     0.300000
# PURCHASES_INSTALLMENTS_FREQUENCY     0.000000     0.166667     0.750000
# CASH_ADVANCE_FREQUENCY               0.000000     0.000000     0.222222
# CASH_ADVANCE_TRX                     0.000000     0.000000     4.000000
# PURCHASES_TRX                        1.000000     7.000000    17.000000
# CREDIT_LIMIT                      1600.000000  3000.000000  6500.000000
# PAYMENTS                           383.276166   856.901546  1901.134317
# MINIMUM_PAYMENTS                   169.123707   312.343947   825.485459
# PRC_FULL_PAYMENT                     0.000000     0.000000     0.142857
# TENURE                              12.000000    12.000000    12.000000
#
#                                           max
# BALANCE                           19043.13856
# BALANCE_FREQUENCY                     1.00000
# PURCHASES                         49039.57000
# ONEOFF_PURCHASES                  40761.25000
# INSTALLMENTS_PURCHASES            22500.00000
# CASH_ADVANCE                      47137.21176
# PURCHASES_FREQUENCY                   1.00000
# ONEOFF_PURCHASES_FREQUENCY            1.00000
# PURCHASES_INSTALLMENTS_FREQUENCY      1.00000
# CASH_ADVANCE_FREQUENCY                1.50000
# CASH_ADVANCE_TRX                    123.00000
# PURCHASES_TRX                       358.00000
# CREDIT_LIMIT                      30000.00000
# PAYMENTS                          50721.48336
# MINIMUM_PAYMENTS                  76406.20752
# PRC_FULL_PAYMENT                      1.00000
# TENURE                               12.00000

# %%
# feel free to investigate what you want
##see if there is duplication
df.duplicated().sum()
# Out:
# 0

# %%
plt.boxplot(df['BALANCE']);

# %%
cat_cols = df.select_dtypes(include=['object']).columns.tolist()
num_cols = df.select_dtypes(exclude=['object']).columns.tolist()

# %%
plt.figure(figsize=(20,20))
corr_data = df.corr()
sns.heatmap(corr_data,annot=True)
plt.show()

# %%
df.hist(figsize = (15,20))
# Out:
# array([[<AxesSubplot:title={'center':'BALANCE'}>,
#         <AxesSubplot:title={'center':'BALANCE_FREQUENCY'}>,
#         <AxesSubplot:title={'center':'PURCHASES'}>,
#         <AxesSubplot:title={'center':'ONEOFF_PURCHASES'}>],
#        [<AxesSubplot:title={'center':'INSTALLMENTS_PURCHASES'}>,
#         <AxesSubplot:title={'center':'CASH_ADVANCE'}>,
#         <AxesSubplot:title={'center':'PURCHASES_FREQUENCY'}>,
#         <AxesSubplot:title={'center':'ONEOFF_PURCHASES_FREQUENCY'}>],
#        [<AxesSubplot:title={'center':'PURCHASES_INSTALLMENTS_FREQUENCY'}>,
#         <AxesSubplot:title={'center':'CASH_ADVANCE_FREQUENCY'}>,
#         <AxesSubplot:title={'center':'CASH_ADVANCE_TRX'}>,
#         <AxesSubplot:title={'center':'PURCHASES_TRX'}>],
#        [<AxesSubplot:title={'center':'CREDIT_LIMIT'}>,
#         <AxesSubplot:title={'center':'PAYMENTS'}>,
#         <AxesSubplot:title={'center':'MINIMUM_PAYMENTS'}>,
#         <AxesSubplot:title={'center':'PRC_FULL_PAYMENT'}>],
#        [<AxesSubplot:title={'center':'TENURE'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df[num_cols].hist(bins=15, figsize=(20, 15), layout=(5, 4));

# %%
df.skew()
# Out:
# C:\Users\elsawah\AppData\Local\Temp/ipykernel_16228/1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# BALANCE                              2.393386
# BALANCE_FREQUENCY                   -2.023266
# PURCHASES                            8.144269
# ONEOFF_PURCHASES                    10.045083
# INSTALLMENTS_PURCHASES               7.299120
# CASH_ADVANCE                         5.166609
# PURCHASES_FREQUENCY                  0.060164
# ONEOFF_PURCHASES_FREQUENCY           1.535613
# PURCHASES_INSTALLMENTS_FREQUENCY     0.509201
# CASH_ADVANCE_FREQUENCY               1.828686
# CASH_ADVANCE_TRX                     5.721298
# PURCHASES_TRX                        4.630655
# CREDIT_LIMIT                         1.522464
# PAYMENTS                             5.907620
# MINIMUM_PAYMENTS                    13.622797
# PRC_FULL_PAYMENT                     1.942820
# TENURE                              -2.943017
# dtype: float64

# %% [markdown]
# ## 3. <a name="3">Data preprocessing</a>
# (<a href="#0">Go to top</a>)

# %% [markdown]
# ### Define below all the issues that you had found in the previous part
# 1-   Handle Nulls        <br>
# 2-    Set cust_ID as index instead of dropping this feature     <br>
# 3-      Scaling to have same range    <br>
# 4- clamping outliers <br>

# %%
#make a copy for the original dataset
df_copy=df.copy()
df_copy
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %% [markdown]
# ### for each issue adapt this methodology
# - start by defining the solution
# - apply this solution onn the data
# - test the solution to make sure that you have solved the issue

# %% [markdown]
# **First issue**

# %%
df_copy.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#we filled the null values with mean values
#My solution
df_copy.fillna(df.mean(axis = 0) , axis = 0 , inplace = True)
# Out:
# C:\Users\elsawah\AppData\Local\Temp/ipykernel_16228/4181304990.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_copy.fillna(df.mean(axis = 0) , axis = 0 , inplace = True)

# %%
#test 
df_copy.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# **Second issue**

# %%
#solution (dropping columns)
## separating the categorical features and numerical features again
num_cols = list(set(df_copy.describe().columns.to_list()) - set(['Id']))
cat_cols = list(set(df_copy.columns.to_list()) - set(num_cols) - set(['Id']))

# inspecting the correlation between each couple of features
num_cols_wthout_response_variable = list(set(num_cols) - set(['PURCHASES']))
corr_matrix = df_copy[num_cols_wthout_response_variable].corr()
corr_matrix
# Out:
#                                    BALANCE  PAYMENTS  MINIMUM_PAYMENTS  \
# BALANCE                           1.000000  0.322802          0.394282
# PAYMENTS                          0.322802  1.000000          0.125046
# MINIMUM_PAYMENTS                  0.394282  0.125046          1.000000
# TENURE                            0.072692  0.106136          0.057257
# CASH_ADVANCE_FREQUENCY            0.449218  0.183192          0.097898
# ONEOFF_PURCHASES_FREQUENCY        0.073166  0.243537         -0.029963
# ONEOFF_PURCHASES                  0.164350  0.567292          0.048597
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186  0.085551          0.029590
# INSTALLMENTS_PURCHASES            0.126469  0.384084          0.131687
# CASH_ADVANCE                      0.496692  0.453238          0.139223
# CASH_ADVANCE_TRX                  0.385152  0.255278          0.109185
# CREDIT_LIMIT                      0.531267  0.421852          0.125134
# PRC_FULL_PAYMENT                 -0.318959  0.112138         -0.139674
# PURCHASES_TRX                     0.154338  0.370832          0.095858
# BALANCE_FREQUENCY                 0.322412  0.065008          0.114249
# PURCHASES_FREQUENCY              -0.077944  0.103464          0.002976
#
#                                     TENURE  CASH_ADVANCE_FREQUENCY  \
# BALANCE                           0.072692                0.449218
# PAYMENTS                          0.106136                0.183192
# MINIMUM_PAYMENTS                  0.057257                0.097898
# TENURE                            1.000000               -0.133372
# CASH_ADVANCE_FREQUENCY           -0.133372                1.000000
# ONEOFF_PURCHASES_FREQUENCY        0.082466               -0.111716
# ONEOFF_PURCHASES                  0.064150               -0.082628
# PURCHASES_INSTALLMENTS_FREQUENCY  0.073275               -0.262958
# INSTALLMENTS_PURCHASES            0.086143               -0.132318
# CASH_ADVANCE                     -0.068312                0.628522
# CASH_ADVANCE_TRX                 -0.043421                0.799561
# CREDIT_LIMIT                      0.139034                0.132616
# PRC_FULL_PAYMENT                 -0.016486               -0.249773
# PURCHASES_TRX                     0.121874               -0.131168
# BALANCE_FREQUENCY                 0.119776                0.191873
# PURCHASES_FREQUENCY               0.061506               -0.308478
#
#                                   ONEOFF_PURCHASES_FREQUENCY  \
# BALANCE                                             0.073166
# PAYMENTS                                            0.243537
# MINIMUM_PAYMENTS                                   -0.029963
# TENURE                                              0.082466
# CASH_ADVANCE_FREQUENCY                             -0.111716
# ONEOFF_PURCHASES_FREQUENCY                          1.000000
# ONEOFF_PURCHASES                                    0.524891
# PURCHASES_INSTALLMENTS_FREQUENCY                    0.142329
# INSTALLMENTS_PURCHASES                              0.214042
# CASH_ADVANCE                                       -0.086754
# CASH_ADVANCE_TRX                                   -0.069088
# CREDIT_LIMIT                                        0.295030
# PRC_FULL_PAYMENT                                    0.157531
# PURCHASES_TRX                                       0.544869
# BALANCE_FREQUENCY                                   0.202415
# PURCHASES_FREQUENCY                                 0.501343
#
#                                   ONEOFF_PURCHASES  \
# BALANCE                                   0.164350
# PAYMENTS                                  0.567292
# MINIMUM_PAYMENTS                          0.048597
# TENURE                                    0.064150
# CASH_ADVANCE_FREQUENCY                   -0.082628
# ONEOFF_PURCHASES_FREQUENCY                0.524891
# ONEOFF_PURCHASES                          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY          0.127729
# INSTALLMENTS_PURCHASES                    0.330622
# CASH_ADVANCE                             -0.031326
# CASH_ADVANCE_TRX                         -0.046212
# CREDIT_LIMIT                              0.319721
# PRC_FULL_PAYMENT                          0.132763
# PURCHASES_TRX                             0.545523
# BALANCE_FREQUENCY                         0.104323
# PURCHASES_FREQUENCY                       0.264937
#
#                                   PURCHASES_INSTALLMENTS_FREQUENCY  \
# BALANCE                                                  -0.063186
# PAYMENTS                                                  0.085551
# MINIMUM_PAYMENTS                                          0.029590
# TENURE                                                    0.073275
# CASH_ADVANCE_FREQUENCY                                   -0.262958
# ONEOFF_PURCHASES_FREQUENCY                                0.142329
# ONEOFF_PURCHASES                                          0.127729
# PURCHASES_INSTALLMENTS_FREQUENCY                          1.000000
# INSTALLMENTS_PURCHASES                                    0.511351
# CASH_ADVANCE                                             -0.177070
# CASH_ADVANCE_TRX                                         -0.169207
# CREDIT_LIMIT                                              0.060752
# PRC_FULL_PAYMENT                                          0.250087
# PURCHASES_TRX                                             0.529975
# BALANCE_FREQUENCY                                         0.176079
# PURCHASES_FREQUENCY                                       0.862934
#
#                                   INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# BALANCE                                         0.126469      0.496692
# PAYMENTS                                        0.384084      0.453238
# MINIMUM_PAYMENTS                                0.131687      0.139223
# TENURE                                          0.086143     -0.068312
# CASH_ADVANCE_FREQUENCY                         -0.132318      0.628522
# ONEOFF_PURCHASES_FREQUENCY                      0.214042     -0.086754
# ONEOFF_PURCHASES                                0.330622     -0.031326
# PURCHASES_INSTALLMENTS_FREQUENCY                0.511351     -0.177070
# INSTALLMENTS_PURCHASES                          1.000000     -0.064244
# CASH_ADVANCE                                   -0.064244      1.000000
# CASH_ADVANCE_TRX                               -0.073999      0.656498
# CREDIT_LIMIT                                    0.256496      0.303983
# PRC_FULL_PAYMENT                                0.182569     -0.152935
# PURCHASES_TRX                                   0.628108     -0.075850
# BALANCE_FREQUENCY                               0.124292      0.099388
# PURCHASES_FREQUENCY                             0.442418     -0.215507
#
#                                   CASH_ADVANCE_TRX  CREDIT_LIMIT  \
# BALANCE                                   0.385152      0.531267
# PAYMENTS                                  0.255278      0.421852
# MINIMUM_PAYMENTS                          0.109185      0.125134
# TENURE                                   -0.043421      0.139034
# CASH_ADVANCE_FREQUENCY                    0.799561      0.132616
# ONEOFF_PURCHASES_FREQUENCY               -0.069088      0.295030
# ONEOFF_PURCHASES                         -0.046212      0.319721
# PURCHASES_INSTALLMENTS_FREQUENCY         -0.169207      0.060752
# INSTALLMENTS_PURCHASES                   -0.073999      0.256496
# CASH_ADVANCE                              0.656498      0.303983
# CASH_ADVANCE_TRX                          1.000000      0.149699
# CREDIT_LIMIT                              0.149699      1.000000
# PRC_FULL_PAYMENT                         -0.169784      0.055671
# PURCHASES_TRX                            -0.066157      0.272877
# BALANCE_FREQUENCY                         0.141555      0.095795
# PURCHASES_FREQUENCY                      -0.203478      0.119778
#
#                                   PRC_FULL_PAYMENT  PURCHASES_TRX  \
# BALANCE                                  -0.318959       0.154338
# PAYMENTS                                  0.112138       0.370832
# MINIMUM_PAYMENTS                         -0.139674       0.095858
# TENURE                                   -0.016486       0.121874
# CASH_ADVANCE_FREQUENCY                   -0.249773      -0.131168
# ONEOFF_PURCHASES_FREQUENCY                0.157531       0.544869
# ONEOFF_PURCHASES                          0.132763       0.545523
# PURCHASES_INSTALLMENTS_FREQUENCY          0.250087       0.529975
# INSTALLMENTS_PURCHASES                    0.182569       0.628108
# CASH_ADVANCE                             -0.152935      -0.075850
# CASH_ADVANCE_TRX                         -0.169784      -0.066157
# CREDIT_LIMIT                              0.055671       0.272877
# PRC_FULL_PAYMENT                          1.000000       0.162066
# PURCHASES_TRX                             0.162066       1.000000
# BALANCE_FREQUENCY                        -0.095082       0.189626
# PURCHASES_FREQUENCY                       0.305802       0.568430
#
#                                   BALANCE_FREQUENCY  PURCHASES_FREQUENCY
# BALANCE                                    0.322412            -0.077944
# PAYMENTS                                   0.065008             0.103464
# MINIMUM_PAYMENTS                           0.114249             0.002976
# TENURE                                     0.119776             0.061506
# CASH_ADVANCE_FREQUENCY                     0.191873            -0.308478
# ONEOFF_PURCHASES_FREQUENCY                 0.202415             0.501343
# ONEOFF_PURCHASES                           0.104323             0.264937
# PURCHASES_INSTALLMENTS_FREQUENCY           0.176079             0.862934
# INSTALLMENTS_PURCHASES                     0.124292             0.442418
# CASH_ADVANCE                               0.099388            -0.215507
# CASH_ADVANCE_TRX                           0.141555            -0.203478
# CREDIT_LIMIT                               0.095795             0.119778
# PRC_FULL_PAYMENT                          -0.095082             0.305802
# PURCHASES_TRX                              0.189626             0.568430
# BALANCE_FREQUENCY                          1.000000             0.229715
# PURCHASES_FREQUENCY                        0.229715             1.000000

# %%
cat_cols
# Out:
# ['CUST_ID']

# %%
# make cust_id as an index
df_copy = df_copy.set_index("CUST_ID")
df_copy
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749           0.818182      95.40              0.00
# C10002   3202.467416           0.909091       0.00              0.00
# C10003   2495.148862           1.000000     773.17            773.17
# C10004   1666.670542           0.636364    1499.00           1499.00
# C10005    817.714335           1.000000      16.00             16.00
# ...              ...                ...        ...               ...
# C19186     28.493517           1.000000     291.12              0.00
# C19187     19.183215           1.000000     300.00              0.00
# C19188     23.398673           0.833333     144.40              0.00
# C19189     13.457564           0.833333       0.00              0.00
# C19190    372.708075           0.666667    1093.25           1093.25
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                    95.40      0.000000             0.166667
# C10002                     0.00   6442.945483             0.000000
# C10003                     0.00      0.000000             1.000000
# C10004                     0.00    205.788017             0.083333
# C10005                     0.00      0.000000             0.083333
# ...                         ...           ...                  ...
# C19186                   291.12      0.000000             1.000000
# C19187                   300.00      0.000000             1.000000
# C19188                   144.40      0.000000             0.833333
# C19189                     0.00     36.558778             0.000000
# C19190                     0.00    127.040008             0.666667
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# C10001                     0.000000                          0.083333
# C10002                     0.000000                          0.000000
# C10003                     1.000000                          0.000000
# C10004                     0.083333                          0.000000
# C10005                     0.083333                          0.000000
# ...                             ...                               ...
# C19186                     0.000000                          0.833333
# C19187                     0.000000                          0.833333
# C19188                     0.000000                          0.666667
# C19189                     0.000000                          0.000000
# C19190                     0.666667                          0.000000
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# CUST_ID
# C10001                 0.000000                 0              2
# C10002                 0.250000                 4              0
# C10003                 0.000000                 0             12
# C10004                 0.083333                 1              1
# C10005                 0.000000                 0              1
# ...                         ...               ...            ...
# C19186                 0.000000                 0              6
# C19187                 0.000000                 0              6
# C19188                 0.000000                 0              5
# C19189                 0.166667                 2              0
# C19190                 0.333333                 2             23
#
#          CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# CUST_ID
# C10001         1000.0   201.802084        139.509787          0.000000      12
# C10002         7000.0  4103.032597       1072.340217          0.222222      12
# C10003         7500.0   622.066742        627.284787          0.000000      12
# C10004         7500.0     0.000000        864.206542          0.000000      12
# C10005         1200.0   678.334763        244.791237          0.000000      12
# ...               ...          ...               ...               ...     ...
# C19186         1000.0   325.594462         48.886365          0.500000       6
# C19187         1000.0   275.861322        864.206542          0.000000       6
# C19188         1000.0    81.270775         82.418369          0.250000       6
# C19189          500.0    52.549959         55.755628          0.250000       6
# C19190         1200.0    63.165404         88.288956          0.000000       6
#
# [8950 rows x 17 columns]

# %% [markdown]
# ## we didn't drop cust_ID we made it as an index which is better

# %%
df_copy
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749           0.818182      95.40              0.00
# C10002   3202.467416           0.909091       0.00              0.00
# C10003   2495.148862           1.000000     773.17            773.17
# C10004   1666.670542           0.636364    1499.00           1499.00
# C10005    817.714335           1.000000      16.00             16.00
# ...              ...                ...        ...               ...
# C19186     28.493517           1.000000     291.12              0.00
# C19187     19.183215           1.000000     300.00              0.00
# C19188     23.398673           0.833333     144.40              0.00
# C19189     13.457564           0.833333       0.00              0.00
# C19190    372.708075           0.666667    1093.25           1093.25
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                    95.40      0.000000             0.166667
# C10002                     0.00   6442.945483             0.000000
# C10003                     0.00      0.000000             1.000000
# C10004                     0.00    205.788017             0.083333
# C10005                     0.00      0.000000             0.083333
# ...                         ...           ...                  ...
# C19186                   291.12      0.000000             1.000000
# C19187                   300.00      0.000000             1.000000
# C19188                   144.40      0.000000             0.833333
# C19189                     0.00     36.558778             0.000000
# C19190                     0.00    127.040008             0.666667
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# C10001                     0.000000                          0.083333
# C10002                     0.000000                          0.000000
# C10003                     1.000000                          0.000000
# C10004                     0.083333                          0.000000
# C10005                     0.083333                          0.000000
# ...                             ...                               ...
# C19186                     0.000000                          0.833333
# C19187                     0.000000                          0.833333
# C19188                     0.000000                          0.666667
# C19189                     0.000000                          0.000000
# C19190                     0.666667                          0.000000
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# CUST_ID
# C10001                 0.000000                 0              2
# C10002                 0.250000                 4              0
# C10003                 0.000000                 0             12
# C10004                 0.083333                 1              1
# C10005                 0.000000                 0              1
# ...                         ...               ...            ...
# C19186                 0.000000                 0              6
# C19187                 0.000000                 0              6
# C19188                 0.000000                 0              5
# C19189                 0.166667                 2              0
# C19190                 0.333333                 2             23
#
#          CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# CUST_ID
# C10001         1000.0   201.802084        139.509787          0.000000      12
# C10002         7000.0  4103.032597       1072.340217          0.222222      12
# C10003         7500.0   622.066742        627.284787          0.000000      12
# C10004         7500.0     0.000000        864.206542          0.000000      12
# C10005         1200.0   678.334763        244.791237          0.000000      12
# ...               ...          ...               ...               ...     ...
# C19186         1000.0   325.594462         48.886365          0.500000       6
# C19187         1000.0   275.861322        864.206542          0.000000       6
# C19188         1000.0    81.270775         82.418369          0.250000       6
# C19189          500.0    52.549959         55.755628          0.250000       6
# C19190         1200.0    63.165404         88.288956          0.000000       6
#
# [8950 rows x 17 columns]

# %%
#third issue
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
Scaler1 = preprocessing.MinMaxScaler()
df_scaled = pd.DataFrame(Scaler1.fit_transform(df_copy) , columns=df_copy.columns)

# %%
#test
print(Scaler1.data_min_)
print(Scaler1.data_max_)
# Out:
# [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#  0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#  5.0000e+01 0.0000e+00 1.9163e-02 0.0000e+00 6.0000e+00]
# [1.90431386e+04 1.00000000e+00 4.90395700e+04 4.07612500e+04
#  2.25000000e+04 4.71372118e+04 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.50000000e+00 1.23000000e+02 3.58000000e+02
#  3.00000000e+04 5.07214834e+04 7.64062075e+04 1.00000000e+00
#  1.20000000e+01]

# %% [markdown]
# ### Fourth Issue

# %%
# IQR method to clamp outliers
def clamping(train_data , num_cols):
    
    for i in num_cols:
        Q1 = np.percentile(train_data[i], q = 25, interpolation = 'midpoint')
        Q3 = np.percentile(train_data[i], q = 75, interpolation = 'midpoint')
        IQR = Q3 - Q1
        
        Upper_Bound = Q3 + (1.5 * IQR)
        Lower_Bound = Q1 - (1.5*IQR)
        train_data.loc[train_data[i] > Upper_Bound , i] = Upper_Bound
        train_data.loc[train_data[i] < Lower_Bound , i] = Lower_Bound
    return train_data

df = clamping(df , num_cols)
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.722223    1499.00           1442.45
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.722223    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   2784.434061             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       0.750000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.357143      12
# 8946   275.861322               NaN          0.000000      12
# 8947    81.270775         82.418369          0.250000      12
# 8948    52.549959         55.755628          0.250000      12
# 8949    63.165404         88.288956          0.000000      12
#
# [8950 rows x 18 columns]

# %% [markdown]
# ## 4. <a name="4">Features transformation</a>
# (<a href="#0">Go to top</a>)

# %% [markdown]
# *What is the feature scaling technique that would use and why?* <br>
# *return to this section again and try another technique and see how that will impact your result*<br>
# for more details on different methods for scaling check these links
# - https://scikit-learn.org/stable/modules/preprocessing.html#preprocessing
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing
# - https://www.analyticsvidhya.com/blog/2020/07/types-of-feature-transformation-and-scaling/

# %% [markdown]
# Answer here:

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.MinMaxScaler()
df_scaled = df_copy.copy()
df_scaled[df_scaled.columns] = scaler.fit_transform(df_scaled.values)
df_scaled
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001   0.002148           0.818182   0.001945          0.000000
# C10002   0.168169           0.909091   0.000000          0.000000
# C10003   0.131026           1.000000   0.015766          0.018968
# C10004   0.087521           0.636364   0.030567          0.036775
# C10005   0.042940           1.000000   0.000326          0.000393
# ...           ...                ...        ...               ...
# C19186   0.001496           1.000000   0.005936          0.000000
# C19187   0.001007           1.000000   0.006118          0.000000
# C19188   0.001229           0.833333   0.002945          0.000000
# C19189   0.000707           0.833333   0.000000          0.000000
# C19190   0.019572           0.666667   0.022293          0.026821
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                 0.004240      0.000000             0.166667
# C10002                 0.000000      0.136685             0.000000
# C10003                 0.000000      0.000000             1.000000
# C10004                 0.000000      0.004366             0.083333
# C10005                 0.000000      0.000000             0.083333
# ...                         ...           ...                  ...
# C19186                 0.012939      0.000000             1.000000
# C19187                 0.013333      0.000000             1.000000
# C19188                 0.006418      0.000000             0.833333
# C19189                 0.000000      0.000776             0.000000
# C19190                 0.000000      0.002695             0.666667
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# C10001                     0.000000                          0.083333
# C10002                     0.000000                          0.000000
# C10003                     1.000000                          0.000000
# C10004                     0.083333                          0.000000
# C10005                     0.083333                          0.000000
# ...                             ...                               ...
# C19186                     0.000000                          0.833333
# C19187                     0.000000                          0.833333
# C19188                     0.000000                          0.666667
# C19189                     0.000000                          0.000000
# C19190                     0.666667                          0.000000
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# CUST_ID
# C10001                 0.000000           0.00000       0.005587
# C10002                 0.166667           0.03252       0.000000
# C10003                 0.000000           0.00000       0.033520
# C10004                 0.055555           0.00813       0.002793
# C10005                 0.000000           0.00000       0.002793
# ...                         ...               ...            ...
# C19186                 0.000000           0.00000       0.016760
# C19187                 0.000000           0.00000       0.016760
# C19188                 0.000000           0.00000       0.013966
# C19189                 0.111111           0.01626       0.000000
# C19190                 0.222222           0.01626       0.064246
#
#          CREDIT_LIMIT  PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# CUST_ID
# C10001       0.031720  0.003979          0.001826          0.000000     1.0
# C10002       0.232053  0.080893          0.014034          0.222222     1.0
# C10003       0.248748  0.012264          0.008210          0.000000     1.0
# C10004       0.248748  0.000000          0.011310          0.000000     1.0
# C10005       0.038397  0.013374          0.003204          0.000000     1.0
# ...               ...       ...               ...               ...     ...
# C19186       0.031720  0.006419          0.000640          0.500000     0.0
# C19187       0.031720  0.005439          0.011310          0.000000     0.0
# C19188       0.031720  0.001602          0.001078          0.250000     0.0
# C19189       0.015025  0.001036          0.000729          0.250000     0.0
# C19190       0.038397  0.001245          0.001155          0.000000     0.0
#
# [8950 rows x 17 columns]

# %%
std_scaler = preprocessing.StandardScaler()
df_std = df_copy.copy()
df_std[df_std.columns] = std_scaler.fit_transform(df_std.values)
df_std.head(5)
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001  -0.731989          -0.249434  -0.424900         -0.356934
# C10002   0.786961           0.134325  -0.469552         -0.356934
# C10003   0.447135           0.518084  -0.107668          0.108889
# C10004   0.049099          -1.016953   0.232058          0.546189
# C10005  -0.358775           0.518084  -0.462063         -0.347294
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                -0.349079     -0.466786            -0.806490
# C10002                -0.454576      2.605605            -1.221758
# C10003                -0.454576     -0.466786             1.269843
# C10004                -0.454576     -0.368653            -1.014125
# C10005                -0.454576     -0.466786            -1.014125
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# C10001                    -0.678661                         -0.707313
# C10002                    -0.678661                         -0.916995
# C10003                     2.673451                         -0.916995
# C10004                    -0.399319                         -0.916995
# C10005                    -0.399319                         -0.916995
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# CUST_ID
# C10001                -0.675349         -0.476070      -0.511333
# C10002                 0.573963          0.110074      -0.591796
# C10003                -0.675349         -0.476070      -0.109020
# C10004                -0.258913         -0.329534      -0.551565
# C10005                -0.675349         -0.476070      -0.551565
#
#          CREDIT_LIMIT  PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT   TENURE
# CUST_ID
# C10001      -0.960433 -0.528979     -3.109675e-01         -0.525551  0.36068
# C10002       0.688639  0.818642      8.931021e-02          0.234227  0.36068
# C10003       0.826062 -0.383805     -1.016632e-01         -0.525551  0.36068
# C10004       0.826062 -0.598688     -4.390474e-16         -0.525551  0.36068
# C10005      -0.905464 -0.364368     -2.657913e-01         -0.525551  0.36068

# %%
normalize_scaler = preprocessing.Normalizer()
df_Norm = df_copy.copy()
df_Norm[df_Norm.columns] = normalize_scaler.fit_transform(df_Norm.values)
df_Norm.head(5)
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001   0.039353           0.000787   0.091790          0.000000
# C10002   0.293876           0.000083   0.000000          0.000000
# C10003   0.310798           0.000125   0.096307          0.096307
# C10004   0.207829           0.000079   0.186921          0.186921
# C10005   0.504284           0.000617   0.009867          0.009867
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                  0.09179      0.000000             0.000160
# C10002                  0.00000      0.591240             0.000000
# C10003                  0.00000      0.000000             0.000125
# C10004                  0.00000      0.025661             0.000010
# C10005                  0.00000      0.000000             0.000051
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# C10001                     0.000000                           0.00008
# C10002                     0.000000                           0.00000
# C10003                     0.000125                           0.00000
# C10004                     0.000010                           0.00000
# C10005                     0.000051                           0.00000
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# CUST_ID
# C10001                 0.000000          0.000000       0.001924
# C10002                 0.000023          0.000367       0.000000
# C10003                 0.000000          0.000000       0.001495
# C10004                 0.000010          0.000125       0.000125
# C10005                 0.000000          0.000000       0.000617
#
#          CREDIT_LIMIT  PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# CUST_ID
# C10001       0.962156  0.194165          0.134230           0.00000  0.011546
# C10002       0.642358  0.376516          0.098404           0.00002  0.001101
# C10003       0.934206  0.077485          0.078135           0.00000  0.001495
# C10004       0.935229  0.000000          0.107764           0.00000  0.001496
# C10005       0.740040  0.418329          0.150963           0.00000  0.007400

# %%
power_scaler = preprocessing.PowerTransformer()
df_power = df_copy.copy()
df_power[df_power.columns] = power_scaler.fit_transform(df_power.values)
df_power.head(5)
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001  -1.238103          -1.079348  -0.368050         -1.000488
# C10002   1.051961          -0.424939  -1.505149         -1.000488
# C10003   0.860616           0.628612   0.521657          1.065381
# C10004   0.570542          -1.710851   0.875823          1.229556
# C10005   0.111925           0.628612  -0.904786         -0.019902
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                 0.383704     -0.944538            -0.766859
# C10002                -1.085422      1.399909            -1.278866
# C10003                -1.085422     -0.944538             1.218860
# C10004                -1.085422      0.680451            -1.015926
# C10005                -1.085422     -0.944538            -1.015926
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# C10001                    -0.903315                         -0.606642
# C10002                    -0.903315                         -1.004445
# C10003                     1.732554                         -1.004445
# C10004                    -0.092230                         -1.004445
# C10005                    -0.092230                         -1.004445
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# CUST_ID
# C10001                -0.883204         -0.905801      -0.573664
# C10002                 1.124423          1.044342      -1.387624
# C10003                -0.883204         -0.905801       0.494757
# C10004                 0.136071          0.194580      -0.872718
# C10005                -0.883204         -0.905801      -0.872718
#
#          CREDIT_LIMIT  PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# CUST_ID
# C10001      -1.425364 -0.983876         -0.849237         -0.677889  0.422252
# C10002       0.924151  1.285321          0.877661          1.235021  0.422252
# C10003       1.012134 -0.291722          0.435065         -0.677889  0.422252
# C10004       1.012134 -2.782085          0.700539         -0.677889  0.422252
# C10005      -1.215737 -0.231669         -0.361555         -0.677889  0.422252

# %%
from sklearn.decomposition import PCA
# Reducing the dimensions of the data 
pca = PCA(n_components = 2) 
X_principal = pca.fit_transform(df_scaled) 
X_principal = pd.DataFrame(X_principal) 
X_principal.columns = ['P1', 'P2'] 
X_principal.head(6)
# Out:
#          P1        P2
# 0 -0.482164 -0.097656
# 1 -0.608577 -0.019379
# 2  0.304507  0.920946
# 3 -0.588622 -0.005605
# 4 -0.554354  0.052965
# 5  0.201438 -0.204677

# %%
model=AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
clust_labels=model.fit_predict(X_principal)
plt.scatter(X_principal.P1,X_principal.P2, c=clust_labels, cmap ='rainbow')
plt.title('Visualisation of clusters')
# Out:
# Text(0.5, 1.0, 'Visualisation of clusters')

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Euclidean distance')
Dendrogram = shc.dendrogram(shc.linkage(X_principal[1:1000], method ='ward'))

# %% [markdown]
# ## 5. <a name="5">K Means</a>
# (<a href="#5">Go to top</a>)

# %% [markdown]
# 1- Use the k means class that you implemented in the previous task to cluster this data
# 2- Use http://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html and see if the difference in the result
# 3- Use elbow method to determine the K (plot the result using two plot one for distorion and another for inertia)
# 4- (Optionally) make a method that pick the best number of clusters for you
# 5- Using different techniques for scaling and comment on the result

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering

# %%
for i in [2,3,4,5,6,7]:
    print(i)
    kmeans = KMeans(n_clusters=i, random_state=0).fit(df_scaled)
    score = silhouette_score(df_scaled, kmeans.labels_, metric='euclidean')
    print(score)
# Out:
# 2
# 0.38672161289328333
# 3
# 0.3723948225544862
# 4
# 0.3215079773343314
# 5
# 0.3190759927360314
# 6
# 0.33423038694681223
# 7
# 0.3374009877234517

# %%
plt.figure(figsize=(10,6))
from sklearn.cluster import KMeans   #Importing our clustering algorithm: KMeans
wcss = []
for i in range(1, 15):
    #Cluster our data by choosing 5 as number of clusters
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 20)
    kmeans.fit(X_principal)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 15), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# list = ['ward' , 'complete' , 'average' , 'single']
# for i in list:
#     cll = AgglomerativeClustering(n_clusters=6  , linkage=i).fit(pca)
#     labels = cll.labels_
#     plt.scatter(pca[: , 0] , pca[: , 1] , c = labels)
#     plt.title(i)
#     plt.show()
#     print(i , sillhouette_score(df_scaled , labels))

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 20)
y_kmeans = kmeans.fit_predict(X_principal)
kmeans.cluster_centers_
# Out:
# array([[ 0.54519649, -0.26861563],
#        [-0.491803  , -0.00392005],
#        [ 0.54832128,  0.49132771]])

# %%
labels=pd.DataFrame(kmeans.labels_)
labels[:8]
# Out:
#    0
# 0  1
# 1  1
# 2  2
# 3  1
# 4  1
# 5  0
# 6  2
# 7  0

# %%
u_labels = np.unique(y_kmeans)
 
#plotting the results:
label= y_kmeans
for i in u_labels:
    plt.scatter(X_principal.P1[label == i] , X_principal.P2[label == i] , label = i)
plt.legend()
plt.show()

# %%
centroids = kmeans.cluster_centers_
u_labels = np.unique(label)
 
#plotting the results:
 
for i in u_labels:
    #plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)
    plt.scatter(X_principal.P1[label == i] , X_principal.P2[label == i] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.show()

# %%
centroids = kmeans.cluster_centers_
centroids
# Out:
# array([[ 0.54519649, -0.26861563],
#        [-0.491803  , -0.00392005],
#        [ 0.54832128,  0.49132771]])

# %%
for i in range(2 , 8):
    print(i)
    kmeans = KMeans(n_clusters=i, random_state=0).fit(df_Norm)
    score = silhouette_score(df_Norm, kmeans.labels_, metric='euclidean')
    print(score)
# Out:
# 2
# 0.29494149478216136
# 3
# 0.3222305054180305
# 4
# 0.34264229240042554
# 5
# 0.35988855201960834
# 6
# 0.35950728415231636
# 7
# 0.3223055060935165

# %%
for i in range(2 , 8):
    print(i)
    kmeans = KMeans(n_clusters=i, random_state=0).fit(df_std)
    score = silhouette_score(df_std, kmeans.labels_, metric='euclidean')
    print(score)
# Out:
# 2
# 0.20950134853896507
# 3
# 0.24996085627555273
# 4
# 0.1976074492720698
# 5
# 0.19323261884327353
# 6
# 0.20259398485856095
# 7
# 0.21501415862714268

# %% [markdown]
# ## 6. <a name="5">Training and hyperparamter tuning</a>
# (<a href="#0">Go to top</a>)

# %% [markdown]
# Before we start the training process we need to specify 3 paramters:<br>
# 1- Linkage criteria : The linkage criterion determines the distance between two clusters
#     - Complete-Linkage Clustering
#     - Single-Linkage Clustering
#     - Average-Linkage Clustering
#     - Centroid Linkage Clustering
# 2- Distance function:
#     - Euclidean Distance
#     - Manhattan Distance
#     - Mahalanobis distance
# 3- Number of clusters

# %% [markdown]
# ### *Number of clusters*
# Use Dendograms to specify the optimum number of clusters
# - Compare how changing linkage criteria or distance function would affect the optimum number of clusters
# - you can use silhouette_score or any other evalution method to help you determine the optimum number of clusters
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html

# %% [markdown]
# ## Euclidean distance

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Euclidean distance')
Dendrogram = shc.dendrogram(shc.linkage(df_scaled[1:1000], method ='ward'))

# %%
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Euclidean distance')
Dendrogram = shc.dendrogram(shc.linkage(df_scaled[1:1000], method ='complete'))

# %%
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Euclidean distance')
Dendrogram = shc.dendrogram(shc.linkage(df_scaled[1:1000], method ='single'))

# %%
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Euclidean distance')
Dendrogram = shc.dendrogram(shc.linkage(df_scaled[1:1000], method ='average') )

# %% [markdown]
# ## Manhattan distance

# %%
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Manhattan distance')
Dendrogram = shc.dendrogram(shc.linkage(df_scaled[1:1000], method ='complete',metric='cityblock'))

# %%
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Manhattan distance')
Dendrogram = shc.dendrogram(shc.linkage(df_scaled[1:1000], method ='complete',metric='cityblock'))

# %%
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Manhattan distance')
Dendrogram = shc.dendrogram(shc.linkage(df_scaled[1:1000], method ='single',metric='cityblock'))

# %% [markdown]
# ## Mahalanobis distance

# %%
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Mahalanobis distance')
Dendrogram = shc.dendrogram(shc.linkage(df_scaled[1:1000], method ='single',metric='Mahalanobis'))

# %%
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Mahalanobis distance')
Dendrogram = shc.dendrogram(shc.linkage(df_scaled[1:1000], method ='complete',metric='Mahalanobis'))

# %%
plt.figure(figsize =(20, 20)) 
plt.title('Dendrograms') 
plt.xlabel('Sample index')
plt.ylabel('Mahalanobis distance')
Dendrogram = shc.dendrogram(shc.linkage(df_scaled[1:1000], method ='average',metric='Mahalanobis'))

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
for i in [2 , 3 , 4 , 5 , 6 ,7]:
    score = AgglomerativeClustering(n_clusters= i , linkage='ward' , affinity='euclidean')
    print(i)
    print(score)
# Out:
# 2
# AgglomerativeClustering()
# 3
# AgglomerativeClustering(n_clusters=3)
# 4
# AgglomerativeClustering(n_clusters=4)
# 5
# AgglomerativeClustering(n_clusters=5)
# 6
# AgglomerativeClustering(n_clusters=6)
# 7
# AgglomerativeClustering(n_clusters=7)

# %%
object1 = K_means(Data_model , 3 , 30)
Kmeans_clustering = object1.k_kmeans_fit()[0]

# %%
#training
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ## 6. <a name="6">improvement ideas</a>
# (<a href="#0">Go to top</a>)

# %% [markdown]
# - Try to use PCA to reduce the number of features and compare how this will affect the clustring process
# - Try to run your code again but with different tranformation technique
# - Implement gap statistics method and use it as evaluation metric and compare the result with what you did before https://www.datanovia.com/en/lessons/determining-the-optimal-number-of-clusters-3-must-know-methods/#gap-statistic-method

# %%
for i in [2,3,4,5,6,7]:
    print(i)
    kmeans = Kmeans(n_clusters=i, random_state=0).fit(x_new)
    print(silhouette_score(x_new, kmeans.labels_))

# %%
kmeans = KMeans(n_clusters=7, random_state=0).fit(x_new)
print(silhouette_score(x_new, kmeans.labels_))
kmeans.labels_

# %% [markdown]
# ## DB SCAN

# %%
# !pip install plotnine
# Out:
# Collecting plotnine
#   Using cached plotnine-0.8.0-py3-none-any.whl (4.7 MB)
# Collecting mizani>=0.7.3
#   Using cached mizani-0.7.4-py3-none-any.whl (63 kB)
# Requirement already satisfied: matplotlib>=3.1.1 in d:\anaconda\lib\site-packages (from plotnine) (3.4.3)
# Collecting descartes>=1.1.0
#   Using cached descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: patsy>=0.5.1 in d:\anaconda\lib\site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: statsmodels>=0.12.1 in d:\anaconda\lib\site-packages (from plotnine) (0.12.2)
# Requirement already satisfied: pandas>=1.1.0 in d:\anaconda\lib\site-packages (from plotnine) (1.4.2)
# Requirement already satisfied: numpy>=1.19.0 in d:\anaconda\lib\site-packages (from plotnine) (1.20.3)
# Requirement already satisfied: scipy>=1.5.0 in d:\anaconda\lib\site-packages (from plotnine) (1.7.1)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (0.10.0)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from cycler>=0.10->matplotlib>=3.1.1->plotnine) (1.16.0)
# Collecting palettable
#   Using cached palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'd:\\anaconda\\lib\\site-packages\\matplotlib\\backends\\_backend_agg.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Collecting matplotlib>=3.1.1
#   Using cached matplotlib-3.5.2-cp39-cp39-win_amd64.whl (7.2 MB)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (21.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=1.1.0->plotnine) (2021.3)
# Installing collected packages: palettable, matplotlib, mizani, descartes, plotnine
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.4.3
#     Uninstalling matplotlib-3.4.3:

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
# !pip install plotnine
import plotnine
# Out:
# Collecting plotnine
#   Using cached plotnine-0.8.0-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: pandas>=1.1.0 in d:\anaconda\lib\site-packages (from plotnine) (1.4.2)
# Requirement already satisfied: patsy>=0.5.1 in d:\anaconda\lib\site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: numpy>=1.19.0 in d:\anaconda\lib\site-packages (from plotnine) (1.20.3)
# Requirement already satisfied: scipy>=1.5.0 in d:\anaconda\lib\site-packages (from plotnine) (1.7.3)
# Requirement already satisfied: matplotlib>=3.1.1 in d:\anaconda\lib\site-packages (from plotnine) (3.4.3)
# Collecting mizani>=0.7.3
#   Using cached mizani-0.7.4-py3-none-any.whl (63 kB)
# Requirement already satisfied: statsmodels>=0.12.1 in d:\anaconda\lib\site-packages (from plotnine) (0.12.2)
# Collecting descartes>=1.1.0
#   Using cached descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (1.3.2)
# Requirement already satisfied: palettable in d:\anaconda\lib\site-packages (from mizani>=0.7.3->plotnine) (3.3.0)
# Collecting matplotlib>=3.1.1
#   Using cached matplotlib-3.5.2-cp39-cp39-win_amd64.whl (7.2 MB)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.1.1->plotnine) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=1.1.0->plotnine) (2021.3)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Installing collected packages: matplotlib, mizani, descartes, plotnine
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.4.3
#     Uninstalling matplotlib-3.4.3:
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'd:\\anaconda\\lib\\site-packages\\matplotlib\\_c_internal_utils.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16228/386333446.py in <module>
#       1 get_ipython().system('pip install plotnine')
# ----> 2 import plotnine
#
# ModuleNotFoundError: No module named 'plotnine'

# %%
df2 = df_Norm
df2.head(5)
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001   0.039353           0.000787   0.091790          0.000000
# C10002   0.293876           0.000083   0.000000          0.000000
# C10003   0.310798           0.000125   0.096307          0.096307
# C10004   0.207829           0.000079   0.186921          0.186921
# C10005   0.504284           0.000617   0.009867          0.009867
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                  0.09179      0.000000             0.000160
# C10002                  0.00000      0.591240             0.000000
# C10003                  0.00000      0.000000             0.000125
# C10004                  0.00000      0.025661             0.000010
# C10005                  0.00000      0.000000             0.000051
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# C10001                     0.000000                           0.00008
# C10002                     0.000000                           0.00000
# C10003                     0.000125                           0.00000
# C10004                     0.000010                           0.00000
# C10005                     0.000051                           0.00000
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# CUST_ID
# C10001                 0.000000          0.000000       0.001924
# C10002                 0.000023          0.000367       0.000000
# C10003                 0.000000          0.000000       0.001495
# C10004                 0.000010          0.000125       0.000125
# C10005                 0.000000          0.000000       0.000617
#
#          CREDIT_LIMIT  PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# CUST_ID
# C10001       0.962156  0.194165          0.134230           0.00000  0.011546
# C10002       0.642358  0.376516          0.098404           0.00002  0.001101
# C10003       0.934206  0.077485          0.078135           0.00000  0.001495
# C10004       0.935229  0.000000          0.107764           0.00000  0.001496
# C10005       0.740040  0.418329          0.150963           0.00000  0.007400

# %%
DB1 = DBSCAN(eps = 0.4 , min_samples= 30 ).fit(df2)

# %%
labsList = ["Noise"]
labsList = labsList  + ["Cluster " + str(i) for i in range(1,len(set(DB1.labels_)))]

df2["assignments"] = DB1.labels_

# (ggplot(df2, aes(x = "BALANCE", y = "PURCHASES", color = "factor(assignments)")) +
#  geom_point() +
#  theme_minimal() +
#  scale_color_discrete(name = "Cluster Assignment",
#                       labels = labsList) +
# theme(panel_grid_major = element_blank()) +
# labs(title = "DBSCAN with eps = {}, min_samples = {}".format(eps_value , min_samples_value)))

# %%
d1 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM1.csv")

z = StandardScaler()
d1[["x","y"]] = z.fit_transform(d1)

ggplot(d1, aes(x = "x", y = "y")) + geom_point() + theme_minimal()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# D:\Anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# D:\Anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# D:\Anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# D:\Anaconda\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1273             raise CannotSendHeader()
# -> 1274         self._send_output(message_body, encode_chunked=encode_chunked)
#    1275
#
# D:\Anaconda\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1033         del self._buffer[:]
# -> 1034         self.send(msg)
#    1035
#
# D:\Anaconda\lib\http\client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# D:\Anaconda\lib\http\client.py in connect(self)
#    1440
# -> 1441             super().connect()
#    1442
#
# D:\Anaconda\lib\http\client.py in connect(self)
#     944         """Connect to the host and port specified in __init__."""
# --> 945         self.sock = self._create_connection(
#     946             (self.host,self.port), self.timeout, self.source_address)
#
# D:\Anaconda\lib\socket.py in create_connection(address, timeout, source_address)
#     822     err = None
# --> 823     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     824         af, socktype, proto, canonname, sa = res
#
# D:\Anaconda\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10692/1200915410.py in <module>
# ----> 1 d1 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM1.csv")
#       2
#       3 z = StandardScaler()
#       4 d1[["x","y"]] = z.fit_transform(d1)
#       5
#
# D:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     678     kwds.update(kwds_defaults)
#     679
# --> 680     return _read(filepath_or_buffer, kwds)
#     681
#     682
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     931
#     932         self.handles: IOHandles | None = None
# --> 933         self._engine = self._make_engine(f, self.engine)
#     934
#     935     def close(self):
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1215             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217             self.handles = get_handle(  # type: ignore[call-overload]
#    1218                 f,
#    1219                 mode,
#
# D:\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     668
#     669     # open URLs
# --> 670     ioargs = _get_filepath_or_buffer(
#     671         path_or_buf,
#     672         encoding=encoding,
#
# D:\Anaconda\lib\site-packages\pandas\io\common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     337         # assuming storage_options is to be interpreted as headers
#     338         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 339         with urlopen(req_info) as req:
#     340             content_encoding = req.headers.get("Content-Encoding", None)
#     341             if content_encoding == "gzip":
#
# D:\Anaconda\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     237     import urllib.request
#     238
# --> 239     return urllib.request.urlopen(*args, **kwargs)
#     240
#     241
#
# D:\Anaconda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# D:\Anaconda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# D:\Anaconda\lib\urllib\request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# D:\Anaconda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# D:\Anaconda\lib\urllib\request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# D:\Anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
# -> 1349                 raise URLError(err)
#    1350             r = h.getresponse()
#    1351         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %%
# dbscan and plot
db1 = DBSCAN(eps = 0.5, min_samples = 25).fit(d1)

labsList = ["Noise"]
labsList = labsList  + ["Cluster " + str(i) for i in range(1,len(set(db1.labels_)))]

d1["assignments"] = db1.labels_

(ggplot(d1, aes(x = "x", y = "y", color = "factor(assignments)")) +
 geom_point() +
 theme_minimal() +
 scale_color_discrete(name = "Cluster Assignment",
                      labels = labsList) +
theme(panel_grid_major = element_blank()) +
labs(title = "DBSCAN with eps = 0.5, min_samples = 25"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10692/2773142010.py in <module>
#       1 # dbscan and plot
# ----> 2 db1 = DBSCAN(eps = 0.5, min_samples = 25).fit(d1)
#       3
#       4 labsList = ["Noise"]
#       5 labsList = labsList  + ["Cluster " + str(i) for i in range(1,len(set(db1.labels_)))]
#
# NameError: name 'd1' is not defined
